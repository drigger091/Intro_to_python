# %%
#creating a stack functionality using list


stack = []

def push():
    n =int(input("Enter the number of elements:"))
    for i in range(0,n):
        add = input(int(n))
        stack.append(add)
        print(stack)

def pop_element():
    if not stack:
        print("The Stack is empty")
    else:
        e = stack.pop()
        print("Removed element is:",e)
        print(stack)
while True: # continous execution of while body
    print("select the operation 1.push 2.pop 3.quit")
    choice = int(input())
    if choice ==1:
        push()
    elif choice== 2:
        pop_element()
    elif choice ==3:
        break
    else:
        print("Select the correct operation")
# Out:
# select the operation 1.push 2.pop 3.quit
# 1
# Enter the number of elements:5
# 51
# ['1']
# 52
# ['1', '2']
# 53
# ['1', '2', '3']
# 54
# ['1', '2', '3', '4']
# 55
# ['1', '2', '3', '4', '5']
# select the operation 1.push 2.pop 3.quit
# 2
# Removed element is: 5
# ['1', '2', '3', '4']
# select the operation 1.push 2.pop 3.quit
# 3

# %%
#putting condition in the list

#creating a stack functionality using list


stack = []

def push():
    
    
    n =int(input("Enter the number of elements:"))
    if n >= number:
        print("the stack is full")
        
    else:
        for i in range(0,n):
            add = input(int(n))
            stack.append(add)
            print(stack)

def pop_element():
    if not stack:
        print("The Stack is empty")
    else:
        e = stack.pop()
        print("Removed element is:",e)
        print(stack)
        
        
number = int(input("limit of the stack:"))
while True: # continous execution of while body
    print("select the operation 1.push 2.pop 3.quit")
    choice = int(input())
    if choice ==1:
        push()
    elif choice== 2:
        pop_element()
    elif choice ==3:
        break
    else:
        print("Select the correct operation")
# Out:
# limit of the stack:8
# select the operation 1.push 2.pop 3.quit
# 1
# Enter the number of elements:9
# the stack is full
# select the operation 1.push 2.pop 3.quit
# 1
# Enter the number of elements:6
# 61
# ['1']
# 62
# ['1', '2']
# 63
# ['1', '2', '3']
# 64
# ['1', '2', '3', '4']
# 65
# ['1', '2', '3', '4', '5']
# 66
# ['1', '2', '3', '4', '5', '6']
# select the operation 1.push 2.pop 3.quit
# 2
# Removed element is: 6
# ['1', '2', '3', '4', '5']
# select the operation 1.push 2.pop 3.quit
# 2
# Removed element is: 5
# ['1', '2', '3', '4']
# select the operation 1.push 2.pop 3.quit
# 2
# Removed element is: 4
# ['1', '2', '3']
# select the operation 1.push 2.pop 3.quit
# 2
# Removed element is: 3
# ['1', '2']
# select the operation 1.push 2.pop 3.quit
# 2
# Removed element is: 2
# ['1']
# select the operation 1.push 2.pop 3.quit
# 2
# Removed element is: 1
# []
# select the operation 1.push 2.pop 3.quit
# 2
# The Stack is empty
# select the operation 1.push 2.pop 3.quit
